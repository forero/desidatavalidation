# %%
# documentations for the LSS catalogs is here
# https://desi.lbl.gov/trac/wiki/keyprojects/y1kp3/clusteringproducts

# %%
import fitsio
import numpy as np
import matplotlib.pyplot as plt

# %%
bgs_lss_file = "/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1/unblinded/BGS_BRIGHT-21.5_clustering.dat.fits"

# %%
bgs_lss_data = fitsio.read(bgs_lss_file)

# %%
bgs_lss_data
# Out:
# array([(39627322701120643, 0.25220979, 1,  21.73359607, -19.37560511, 'S', 0.93721414, 1., 0.29562407, 0.93559164, 0.93559164, 1., 20.810436 , 73.10186 , 149.16689 , 135.6446  ,  99.00061 ),
#        (39627322701123557, 0.37635243, 1,  21.81457446, -19.38500467, 'S', 0.93721414, 1., 0.3052246 , 0.93559164, 0.93559164, 1.,  5.455156 , 26.550306,  58.063454,  92.51501 ,  56.048416),
#        (39627322701123768, 0.2530706 , 1,  21.82139998, -19.41746024, 'S', 0.93721414, 1., 0.29562407, 0.93559164, 1.87118328, 2., 18.194235 , 61.44949 , 115.34717 , 124.56431 ,  86.61836 ),
#        ...,
#        (39637324534912000, 0.35935823, 3, 256.70061154,  32.35785433, 'S', 1.        , 1., 0.30498459, 0.99487537, 0.99487537, 1.,  5.522908 , 25.370857,  56.02223 ,  85.09881 ,  53.61978 ),
#        (39637325784813891, 0.35111693, 1, 344.59157944,  32.14275722, 'S', 0.94260307, 1., 0.30498459, 1.04781353, 2.09562707, 2.,  6.8113103, 26.863104,  57.680225,  77.364204,  55.237717),
# ...

# %%
len(bgs_lss_data)
# Out:
# 300017

# %%
plt.scatter(bgs_lss_data['RA'], bgs_lss_data['DEC'], s=0.1)

# %%
plt.hist(bgs_lss_data['Z'], bins=20)
# Out:
# (array([ 2553.,  3791.,  4828.,  5568.,  6595.,  8138.,  9355., 10232.,
#         11933., 12821., 14555., 16647., 17725., 18998., 20592., 23002.,
#         25635., 27601., 29271., 30177.]),
#  array([0.10003384, 0.11503212, 0.13003041, 0.14502869, 0.16002697,
#         0.17502525, 0.19002353, 0.20502181, 0.22002009, 0.23501837,
#         0.25001665, 0.26501493, 0.28001321, 0.29501149, 0.31000977,
#         0.32500805, 0.34000633, 0.35500461, 0.37000289, 0.38500118,
#         0.39999946]),
#  <BarContainer object of 20 artists>)

# %%
lrg_lss_file = "/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1/unblinded/LRG_clustering.dat.fits"
lrg_lss_data = fitsio.read(lrg_lss_file)

# %%
len(lrg_lss_data)
# Out:
# 2138600

# %%
plt.hist(lrg_lss_data['Z'])
# Out:
# (array([145460., 177131., 217779., 245924., 268298., 320146., 307365.,
#         236659., 144072.,  75766.]),
#  array([0.40000034, 0.47000026, 0.54000018, 0.6100001 , 0.68000003,
#         0.74999995, 0.81999987, 0.88999979, 0.95999971, 1.02999963,
#         1.09999955]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(lrg_lss_data['RA'], lrg_lss_data['DEC'], s=0.1)
